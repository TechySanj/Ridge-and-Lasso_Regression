# %% [markdown]
# <a href="https://colab.research.google.com/github/TechySanj/Ridge-and-Lasso_Regression/blob/main/Ridge%26LassoRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Step 1: Gathering dataset**

# %%
#importing the packages
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/insurance.csv")
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# # **Step** **2**: **Data** **Cleaning**

# %%
#one hot encoding
data['sex']=data['sex'].apply({'male':1,'female':2}.get)

# %%
data.head()
# Out:
#    age  sex   bmi  children smoker     region  expenses
# 0   19    2  27.9         0    yes  southwest  16884.92
# 1   18    1  33.8         1     no  southeast   1725.55
# 2   28    1  33.0         3     no  southeast   4449.46
# 3   33    1  22.7         0     no  northwest  21984.47
# 4   32    1  28.9         0     no  northwest   3866.86

# %%
data['smoker']=data['smoker'].apply({'yes':1,'no':0}.get)

# %%
data.head()
# Out:
#    age  sex   bmi  children  smoker     region  expenses
# 0   19    2  27.9         0       1  southwest  16884.92
# 1   18    1  33.8         1       0  southeast   1725.55
# 2   28    1  33.0         3       0  southeast   4449.46
# 3   33    1  22.7         0       0  northwest  21984.47
# 4   32    1  28.9         0       0  northwest   3866.86

# %%
data['region']=data['region'].apply({'southeast':1,'southwest':2,'northeast':3,'northwest':4}.get)

# %%
data.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    2  27.9         0       1       2  16884.92
# 1   18    1  33.8         1       0       1   1725.55
# 2   28    1  33.0         3       0       1   4449.46
# 3   33    1  22.7         0       0       4  21984.47
# 4   32    1  28.9         0       0       4   3866.86

# %% [markdown]
# # **Step 3 : Divide the Data into Independent and Dependent**

# %%
x=data[['age','sex','bmi','children','smoker','region']]#independent column
y=data['expenses']#dependent column

# %% [markdown]
# # **Step 4: Splitting the data into train and test set**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8) #means 80% data for training and 20% data for testing

# %% [markdown]
# # **Creating MLM using LinearRegression algorithm**

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression() #activating the algorithm

# %%
regression.fit(x_train,y_train) #training the MLM with the help of .fit()
# Out:
# LinearRegression()

# %%
predictions=regression.predict(x_test)#future predictions by MLM

# %%
print(predictions)
# Out:
# [35082.22983882  7542.74064661 10345.50824353  6712.32519288
#  39206.80024304 15088.43439924  7957.75269016 10484.64063476
#  34763.6626812   6203.06366847  4402.55691572  7379.7306168
#   3189.43729941 12041.6624905  14794.48808703 31560.12997749
#  14112.67454027  8628.52244649 15039.30193538 12050.99759648
#  34056.12772866  5272.50682566  4634.5785335  13840.45210608
#   8115.98783382 23450.3584309  26710.08324501  9052.42857588
#  10827.54930134 16673.29464423  4380.53522083 33514.6411147
#   8389.77653371 29297.74251631 14312.97402158  6170.52878774
#  12511.14950727  4737.02094239  5035.5477898  10978.12212156
#   6747.10507832  2229.04644196 10689.59586514  9641.91392847
#  12543.67272754  1638.62306093  3376.06341199 30802.67980089
#  30189.23588017  9929.10278083  5430.85880077 15439.68730906
#   5050.62985039 13385.96963041 12719.36342841 15435.01279265
#   5319.20977781  8575.67908196  8924.94350022  3542.20093052
#  30281.64293968 10847.30314128  4284.50457871  -138.7739722
#   7644.36232918  9737.44800603  8760.88892513 12757.06665305
#    757.65407269 13224.71835535 10155.32210176 11419.83795396
#   3786.21643212 12138.50401499  2578.95921067  6855.70987465
#   3736.2964068   1575.7379585   -641.12990233 13663.43519094
#  11996.73796255 31711.1769827  11766.29106319 35675.09118428
#   8173.42204817  2529.0163351  10437.49348167  5796.99854507
#  38560.12072752 13123.28918877 15297.58634881  6024.29557613
#   4760.53324537 14146.83650305 11584.54361655  8526.72473658
#  12123.72921071 14429.93745867 13154.66749404 11847.00598183
#  11070.6572023  12953.24507278   588.1037842  18406.77238273
#  11700.91198123  8347.27830973 27056.37909425 31490.57294368
#  33745.41538354 36295.46541139  7512.65812783 32459.2856648
#   4176.69447765  8404.42284609 12016.67310176  5541.00396165
#   3879.30135546  5877.40367252 12151.29624557  5950.76879595
#   9572.92637977 11902.74543857  4770.0608404   2384.28258881
#  17454.9702167  30742.09571825 15342.65055845 35489.3955226
#  11813.91006872 30361.56982618  2800.83618593 10434.50614531
#   7270.69193414 15662.11412693  8172.34433804  9520.98787883
#  31066.28708118 11978.02065889  4433.32895879 11737.71879502
#  14571.99318911 38370.4512635   6836.25023934  8991.40029231
#  11221.24442004  3231.29562567  5185.00040714 26379.81275674
#  39956.61487253 35547.60610862  7687.62526438 13460.46527132
#   7084.5936891   9869.3474335   4921.59727636  5579.73919594
#  36377.42648994  6032.33442496 10056.21086043  9319.63266245
#  37743.74806104 18757.55871205  6593.72301328  7506.51771545
#  13676.68808416  6316.88569    10316.93597535 12949.10961369
#  14974.68803532 27692.09642173 16649.42732026 25728.78244283
#  13076.77872568 13237.68343247 10038.49834636 17367.62633012
#  32012.33702066  1010.26992618   924.13815948 29923.96747781
#   6279.24648944 12218.81908733  8967.85668636 10795.49266157
#  16544.83476305  3097.81827204  9746.47332083  9637.95131592
#  15117.15753889  7406.04621982 24966.80382003 26365.59898483
#   4579.93071373 14041.52038152 31553.84670263  9403.10081081
#  -1011.9213128   5924.31351124 29158.5989353  14815.85781924
#  30662.3416783  32966.31611134 30401.78940992 28839.44468732
#   8108.49835692 28879.66427106 12351.95074787 12075.61844188
#   4404.97202991  7374.79593579  8383.54606621 13277.89182643
#   2738.89184899  9424.67742959 15495.85977695  9096.61077217
#   7131.17135708  1406.7487024   4770.0608404   9776.30733547
#  30385.99818253 11776.5753874  35004.84929548 12779.22715446
#   1447.14113268  -521.76254083 12400.57772376 15863.06557092
#  38128.54108491  9849.14459136 11762.40092746 12910.43432058
#   6922.09506511  5085.44817261 33281.31204998  9130.50138057
#  35349.33268048  8114.91012369  7272.74171274 12613.24808496
#  27766.38791313  3928.54351695 15415.91004021  7351.02985672
#   4392.62673732 32874.27485811 36971.13942095 26977.7699693
#  26967.99066239 40265.61008047 -2148.76805301  4429.92737862
#  14993.1044712   8969.03564139 28976.09475948 15334.027827
#  12384.19142397 11358.31584289  9592.3260739  34221.82104626
#   3342.8166274  12166.67643687 27394.6804493   5054.32956128
#   8956.89449832 36924.81346486  7424.45099524 39298.62341992]

# %%
regression.score(x,y)  #output if more than 60% that means the project is reliable here it is 75%
# Out:
# 0.7502279568838132

# %% [markdown]
# # **predictions on top of new dataset**

# %%
data_new={'age':65,'sex':1,'bmi':23,'children':3,'smoker':0,'region':2}
index=[1] #serial number

# %%
my_data=pd.DataFrame(data_new,index)

# %%
my_data
# Out:
#    age  sex  bmi  children  smoker  region
# 1   65    1   23         3       0       2

# %%
new_predictions=regression.predict(my_data)

# %%
print("the health insurance cost for the new customer is",new_predictions)
# Out:
# the health insurance cost for the new customer is [13367.07102748]

# %%
from sklearn.linear_model import Ridge
ridge=Ridge(alpha=2)
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=2)

# %%
predictions_ridge=ridge.predict(x_test)

# %%
ridge.score(x,y)
# Out:
# 0.7500749848013244

# %% [markdown]
# # **Creating MLM using LinearRegression algorithm**

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=2)
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=2)

# %%
predictions_lasso=lasso.predict(x_test)

# %%
lasso.score(x,y)
# Out:
# 0.750225478140971
